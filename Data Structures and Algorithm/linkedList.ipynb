# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    # insert an element at the end of the linked list
    def append(self, data):
        new_node = Node(data)
        # empty list case
        if self.head is None:
            self.head = new_node
            return
        # non-empty list case
        last_node = self.head
        while last_node:
            last_node = last_node.next
        last_node.next = new_node

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    # insert an element at the beginning of the linked list
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    # insert after node
    def insert_after_node(self, prev_node, data):
        if not prev_node:
            print("Previous node does not exist.")
            return
        new_node = Node(data)

        new_node.next = prev_node.next
        prev_node.next = new_node

llist = LinkedList()
llist.append("A")
llist.append("B")
llist.append("C")
llist.append("D")

llist.insert_after_node(llist.head.next, "E")
llist.print_list()

# %%
# Deletion by Value
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    # print the list
    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next
        
    # insert the node at the end of the linked list
    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        last_node = self.head
        while last_node:
            last_node = last_node.next
        last_node.next = new_node

    
    # insert the node at the beginning of the linked list
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    # insert the node after specific node
    def insert_after_node(self, prev_node, data):
        if not prev_node:
            print("Previouse node does not exist")
            return
        new_node = Node(data)

        new_node.next = prev_node.next
        prev_node.next = new_node

    # delete the node by value
    def delete_node(self, key):
        # if the value is the head node
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.node = cur_node.next
            cur_node = None
            return

        # if the value is not the head node
        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next

        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

llist = LinkedList()
llist.append("A")
llist.append("B")
llist.append("C")
llist.append("D")

llist.delete_node("B")
llist.delete_node("E")

llist.print_list()

# %%
# Deletion by Position

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node:
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

llist = LinkedList()
print("The length of an empty linked list is: ")
print(llist.len_iterative())
print(llist.len_recursive(llist.head))

llist.append("A")
llist.append("B")
llist.append("C")
llist.append("D")

print("The length of the linked list calculated recursively after inserting 4 elements:")
print(llist.len_recursive(llist.head))
print("The length of the linked list calculated iteratively after inserting 4 elements:")
print(llist.len_iterative())

# %%
# Node Swap

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node:
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next
        
llist = LinkedList()
llist.append(1) 
# llist.append(2)
llist.append(3)
llist.append(4)
# llist.print_list()

llist.swap_node(1, 3)

llist.print_list()

# %%
# merge two sorted linked list
# two sorted linked list's value should not be overlapped

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            # print(last_node.data)
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next

    def merge_sorted(self, llist):
    
        p = self.head 
        q = llist.head
        s = None
    
        if not p:
            return q
        if not q:
            return p

        if p and q:
            if p.data <= q.data:
                s = p 
                p = s.next
            else:
                s = q
                q = s.next
            new_head = s 
        while p and q:
            if p.data <= q.data:
                s.next = p 
                s = p 
                p = s.next
            else:
                s.next = q
                s = q
                q = s.next
        if not p:
            s.next = q 
        if not q:
            s.next = p 
        return new_head

llist = LinkedList()
llist.append(1) 
llist.append(3)
llist.append(5)
llist.append(7)
# llist.print_list()

lst = LinkedList()
lst.append(2)
lst.append(4)
lst.append(6)
llist.merge_sorted(lst)
print("merge sorted linked list: ")
print(llist.print_list())

# %%
# merge two sorted linked list
# two sorted linked list's value should not be overlapped

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            # print(last_node.data)
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next

    def merge_sorted(self, llist):
    
        p = self.head 
        q = llist.head
        s = None
    
        if not p:
            return q
        if not q:
            return p

        if p and q:
            if p.data <= q.data:
                s = p 
                p = s.next
            else:
                s = q
                q = s.next
            new_head = s 
        while p and q:
            if p.data <= q.data:
                s.next = p 
                s = p 
                p = s.next
            else:
                s.next = q
                s = q
                q = s.next
        if not p:
            s.next = q 
        if not q:
            s.next = p 
        return new_head

llist = LinkedList()
llist.append(1) 
llist.append(3)
llist.append(5)
llist.append(7)
# llist.print_list()

lst = LinkedList()
lst.append(2)
lst.append(4)
lst.append(6)
llist.merge_sorted(lst)
print("merge sorted linked list: ")
print(llist.print_list())

# %%
# remove the duplicates in linked list

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            # print(last_node.data)
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next

    def merge_sorted(self, llist):
    
        p = self.head 
        q = llist.head
        s = None
    
        if not p:
            return q
        if not q:
            return p

        if p and q:
            if p.data <= q.data:
                s = p 
                p = s.next
            else:
                s = q
                q = s.next
            new_head = s 
        while p and q:
            if p.data <= q.data:
                s.next = p 
                s = p 
                p = s.next
            else:
                s.next = q
                s = q
                q = s.next
        if not p:
            s.next = q 
        if not q:
            s.next = p 
        return new_head

    def remove_duplicates(self):
        cur = self.head
        prev  = None
        dup_values = dict()

        while cur:
            if cur.data in dup_values:
                prev.next = cur.next
                cur = None
            else:
                dup_values[cur.data] = 1
                prev = cur
                cur = cur.next

llist = LinkedList()
llist.append(1) 
llist.append(3)
llist.append(3)
llist.append(7)
llist.append(4)
llist.remove_duplicates()
llist.print_list()

# %%
# Nth-to-Last node

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            # print(last_node.data)
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next

    def merge_sorted(self, llist):
    
        p = self.head 
        q = llist.head
        s = None
    
        if not p:
            return q
        if not q:
            return p

        if p and q:
            if p.data <= q.data:
                s = p 
                p = s.next
            else:
                s = q
                q = s.next
            new_head = s 
        while p and q:
            if p.data <= q.data:
                s.next = p 
                s = p 
                p = s.next
            else:
                s.next = q
                s = q
                q = s.next
        if not p:
            s.next = q 
        if not q:
            s.next = p 
        return new_head

    def remove_duplicates(self):
        cur = self.head
        prev  = None
        dup_values = dict()

        while cur:
            if cur.data in dup_values:
                prev.next = cur.next
                cur = None
            else:
                dup_values[cur.data] = 1
                prev = cur
                cur = cur.next

    # Nth-to-last node
    def print_nth_from_last(self, n, method):
        if method == 1:
            length = self.len_iterative()
            cur = self.head
            while cur:
                if length == n:
                    return cur.data            
                cur = cur.next
                length -= 1
            if cur is None:
                return
           
        elif method == 2:
            p = self.head
            q = self.head
            cnt = 0
            while q:
                cnt += 1
                if cnt >= n:
                    break
                q = q.next
            if not q:
                print(str(n) + " is greater than the number of nodes in list.")
                return

            while p and q.next:
                q = q.next
                p = p.next
            return p.data

llist = LinkedList()
llist.append(1) 
llist.append(3)
llist.append(3)
llist.append(7)
llist.append(4)
print(llist.print_nth_from_last(5, 1))
print(llist.print_nth_from_last(5, 2))

# %%
# count occurrences

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            # print(last_node.data)
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next

    def merge_sorted(self, llist):
    
        p = self.head 
        q = llist.head
        s = None
    
        if not p:
            return q
        if not q:
            return p

        if p and q:
            if p.data <= q.data:
                s = p 
                p = s.next
            else:
                s = q
                q = s.next
            new_head = s 
        while p and q:
            if p.data <= q.data:
                s.next = p 
                s = p 
                p = s.next
            else:
                s.next = q
                s = q
                q = s.next
        if not p:
            s.next = q 
        if not q:
            s.next = p 
        return new_head

    def remove_duplicates(self):
        cur = self.head
        prev  = None
        dup_values = dict()

        while cur:
            if cur.data in dup_values:
                prev.next = cur.next
                cur = None
            else:
                dup_values[cur.data] = 1
                prev = cur
                cur = cur.next

    # Nth-to-last node
    def print_nth_from_last(self, n, method):
        if method == 1:
            length = self.len_iterative()
            cur = self.head
            while cur:
                if length == n:
                    return cur.data            
                cur = cur.next
                length -= 1
            if cur is None:
                return
           
        elif method == 2:
            p = self.head
            q = self.head
            cnt = 0
            while q:
                cnt += 1
                if cnt >= n:
                    break
                q = q.next
            if not q:
                print(str(n) + " is greater than the number of nodes in list.")
                return

            while p and q.next:
                q = q.next
                p = p.next
            return p.data

    def count_occurrences_iteratives(self, data):
        cur = self.head
        cnt = 0
        while cur:
            if cur.data == data:
                cnt += 1
            cur = cur.next
        return cnt
        
    def count_occurrences_recursives(self, cur, data):
        if cur is None:
            return 0
        if cur.data == data:
            return self.count_occurrences_recursives(cur.next, data) + 1
        else:
            return self.count_occurrences_recursives(cur.next, data)

llist = LinkedList()
llist.append(1) 
llist.append(3)
llist.append(3)
llist.append(7)
llist.append(4)
print(llist.count_occurrences_iteratives(4))
print(llist.count_occurrences_recursives(llist.head, 4))

# %%
# rotate

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            # print(last_node.data)
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next

    def merge_sorted(self, llist):
    
        p = self.head 
        q = llist.head
        s = None
    
        if not p:
            return q
        if not q:
            return p

        if p and q:
            if p.data <= q.data:
                s = p 
                p = s.next
            else:
                s = q
                q = s.next
            new_head = s 
        while p and q:
            if p.data <= q.data:
                s.next = p 
                s = p 
                p = s.next
            else:
                s.next = q
                s = q
                q = s.next
        if not p:
            s.next = q 
        if not q:
            s.next = p 
        return new_head

    def remove_duplicates(self):
        cur = self.head
        prev  = None
        dup_values = dict()

        while cur:
            if cur.data in dup_values:
                prev.next = cur.next
                cur = None
            else:
                dup_values[cur.data] = 1
                prev = cur
                cur = cur.next

    # Nth-to-last node
    def print_nth_from_last(self, n, method):
        if method == 1:
            length = self.len_iterative()
            cur = self.head
            while cur:
                if length == n:
                    return cur.data            
                cur = cur.next
                length -= 1
            if cur is None:
                return
           
        elif method == 2:
            p = self.head
            q = self.head
            cnt = 0
            while q:
                cnt += 1
                if cnt >= n:
                    break
                q = q.next
            if not q:
                print(str(n) + " is greater than the number of nodes in list.")
                return

            while p and q.next:
                q = q.next
                p = p.next
            return p.data

    def count_occurrences_iteratives(self, data):
        cur = self.head
        cnt = 0
        while cur:
            if cur.data == data:
                cnt += 1
            cur = cur.next
        return cnt
        
    def count_occurrences_recursives(self, cur, data):
        if cur is None:
            return 0
        if cur.data == data:
            return self.count_occurrences_recursives(cur.next, data) + 1
        else:
            return self.count_occurrences_recursives(cur.next, data)

    def rotate(self,k):
        if self.head and self.head.next:
            cur = self.head
            end = self.head
            prev = None
            n = 0

            while cur and n < k:
                prev = cur
                cur = cur.next
                end = end.next
                n += 1
            cur = prev
            while end:
                prev = end
                end = end.next
            end = prev
            end.next = self.head
            self.head = cur.next
            cur.next = None


llist = LinkedList()
llist.append(1) 
llist.append(3)
llist.append(3)
llist.append(7)
llist.append(4)
llist.rotate(3)
llist.print_list()

# %%
# check palindrome

class Stack():
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        return self.items.pop()

    def is_empty(self):
        return self.items == []

    def peek(self):
        if self.is_empty():
            return self.items[-1]

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            # print(last_node.data)
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next

    def merge_sorted(self, llist):
    
        p = self.head 
        q = llist.head
        s = None
    
        if not p:
            return q
        if not q:
            return p

        if p and q:
            if p.data <= q.data:
                s = p 
                p = s.next
            else:
                s = q
                q = s.next
            new_head = s 
        while p and q:
            if p.data <= q.data:
                s.next = p 
                s = p 
                p = s.next
            else:
                s.next = q
                s = q
                q = s.next
        if not p:
            s.next = q 
        if not q:
            s.next = p 
        return new_head

    def remove_duplicates(self):
        cur = self.head
        prev  = None
        dup_values = dict()

        while cur:
            if cur.data in dup_values:
                prev.next = cur.next
                cur = None
            else:
                dup_values[cur.data] = 1
                prev = cur
                cur = cur.next

    # Nth-to-last node
    def print_nth_from_last(self, n, method):
        if method == 1:
            length = self.len_iterative()
            cur = self.head
            while cur:
                if length == n:
                    return cur.data            
                cur = cur.next
                length -= 1
            if cur is None:
                return
           
        elif method == 2:
            p = self.head
            q = self.head
            cnt = 0
            while q:
                cnt += 1
                if cnt >= n:
                    break
                q = q.next
            if not q:
                print(str(n) + " is greater than the number of nodes in list.")
                return

            while p and q.next:
                q = q.next
                p = p.next
            return p.data

    def count_occurrences_iteratives(self, data):
        cur = self.head
        cnt = 0
        while cur:
            if cur.data == data:
                cnt += 1
            cur = cur.next
        return cnt
        
    def count_occurrences_recursives(self, cur, data):
        if cur is None:
            return 0
        if cur.data == data:
            return self.count_occurrences_recursives(cur.next, data) + 1
        else:
            return self.count_occurrences_recursives(cur.next, data)

    def rotate(self,k):
        if self.head and self.head.next:
            cur = self.head
            end = self.head
            prev = None
            n = 0

            while cur and n < k:
                prev = cur
                cur = cur.next
                end = end.next
                n += 1
            cur = prev
            while end:
                prev = end
                end = end.next
            end = prev
            end.next = self.head
            self.head = cur.next
            cur.next = None

    def reverse(self):
        cur = self.head
        prev = None
        while cur:
            nxt = cur.next
            cur.next = prev
            prev = cur
            cur = nxt
        self.head = prev


    def is_palindrome(self, method):
        if method == 1:
        # using reverse
            p = self.head
            cur = self.head
            prev = None
            while cur:
                nxt = cur.next
                cur.next = prev
                prev = cur
                cur = nxt
            q = prev
            check = True
            while p and q:
                if p.data != q.data:
                    check = False
                    break
                else:
                    p = p.next
                    q = q.next
            return check
        elif method == 2:
            s = ""
            cur = self.head
            while cur:
                s += str(cur.data)
                cur = cur.next
            if s == s[::-1]:
                return True
            else:
                return False
        elif method == 3:
            # using stack
            s = Stack()
            cur = self.head
            while cur:
                s.push(cur.data)
                cur = cur.next
            while self.head:
                if s.pop() != self.head.data:
                    return False
                self.head = self.head.next
            return True
        elif method == 4:
            # using list
            s = []
            cur = self.head
            while cur:
                s.append(cur.data)
                cur = cur.next
            cur = self.head
            while cur:
                if s.pop() != cur.data:
                    return False
                cur = cur.next
            return True


llist = LinkedList()
llist.append(1) 
llist.append(3)
llist.append(3)
llist.append(2)

print(llist.is_palindrome(4))
# Out:
# False
