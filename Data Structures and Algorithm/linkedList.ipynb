# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    # insert an element at the end of the linked list
    def append(self, data):
        new_node = Node(data)
        # empty list case
        if self.head is None:
            self.head = new_node
            return
        # non-empty list case
        last_node = self.head
        while last_node.next:
            last_node = last_node.next
        last_node.next = new_node

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    # insert an element at the beginning of the linked list
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    # insert after node
    def insert_after_node(self, prev_node, data):
        if not prev_node:
            print("Previous node does not exist.")
            return
        new_node = Node(data)

        new_node.next = prev_node.next
        prev_node.next = new_node

llist = LinkedList()
llist.append("A")
llist.append("B")
llist.append("C")
llist.append("D")

llist.insert_after_node(llist.head.next, "E")
llist.print_list()
# Out:
# A
# B
# E
# C
# D

# %%
# Deletion by Value
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    # print the list
    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next
        
    # insert the node at the end of the linked list
    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        last_node = self.head
        while last_node.next:
            last_node = last_node.next
        last_node.next = new_node

    
    # insert the node at the beginning of the linked list
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    # insert the node after specific node
    def insert_after_node(self, prev_node, data):
        if not prev_node:
            print("Previouse node does not exist")
            return
        new_node = Node(data)

        new_node.next = prev_node.next
        prev_node.next = new_node

    # delete the node by value
    def delete_node(self, key):
        # if the value is the head node
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.node = cur_node.next
            cur_node = None
            return

        # if the value is not the head node
        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next

        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

llist = LinkedList()
llist.append("A")
llist.append("B")
llist.append("C")
llist.append("D")

llist.delete_node("B")
llist.delete_node("E")

llist.print_list()
# Out:
# A
# C
# D

# %%
# Deletion by Position

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

llist = LinkedList()
print("The length of an empty linked list is: ")
print(llist.len_iterative())
print(llist.len_recursive(llist.head))

llist.append("A")
llist.append("B")
llist.append("C")
llist.append("D")

print("The length of the linked list calculated recursively after inserting 4 elements:")
print(llist.len_recursive(llist.head))
print("The length of the linked list calculated iteratively after inserting 4 elements:")
print(llist.len_iterative())
# Out:
# The length of an empty linked list is:
# 0
# 0
# The length of the linked list calculated recursively after inserting 4 elements:
# 4
# The length of the linked list calculated iteratively after inserting 4 elements:
# 4

# %%
# Node Swap

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next

    def append(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head
        while last_node.next:
            last_node = last_node.next
        last_node.next = new_node
    
    def prepend(self, data):
        new_node = Node(data)

        new_node.next = self.head
        self.head = new_node

    def insert_after_node(self, prev_node, data):
        if  not prev_node:
            print("Previouse node does not exist")
            return

        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node


    def delete_node(self, key):
        cur_node = self.head
        if cur_node and cur_node.data == key:
            self.head = cur_node.next
            cur_node = None
            return

        prev = None
        while cur_node and cur_node.data != key:
            prev = cur_node
            cur_node = cur_node.next
        
        if cur_node is None:
            return

        prev.next = cur_node.next
        cur_node = None

    # delete the node at specific position    
    def delete_node_at_pose(self, pos):
        cur_node = self.head
        index = 0
        if cur_node and pos == index:
            self.head = cur_node.next
            cur_node = None
            return
        
        prev = None
        while cur_node and pos != index:
            prev = cur_node
            index += 1
            cur_node = cur_node.next

        if cur_node is None:
            return
        
        prev.next = cur_node.next
        cur_node = None
        
    # calculate the length of the linked list
    def len_iterative(self):
        length = 0
        cur_node = self.head
        while cur_node:
            length += 1
            cur_node = cur_node.next
        return length

    # calculate the length of the linked list by recursive
    def len_recursive(self, node):
        if node is None:
            return 0
        return self.len_recursive(node.next) + 1

    # swap nodes
    def swap_node(self, key_1, key_2):
        if key_1 == key_2:
            return
        
        prev_1 = None
        cur_1 = self.head
        while cur_1 and cur_1.data != key_1:
            prev_1 = cur_1
            cur_1 = cur_1.next
        
        prev_2 = None
        cur_2 = self.head
        while cur_2 and cur_2.data != key_2:
            prev_2 = cur_2
            cur_2 = cur_2.next

        if not cur_1 or not cur_2:
            return

        if prev_1:
            prev_1.next = cur_2
        else:
            self.head.next = cur_2

        if prev_2:
            prev_2.next = cur_1
        else:
            self.head.next = cur_1

        cur_1.next , cur_2.next = cur_2.next, cur_1.next
