# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        if self.head is None:
            self.head = Node(data)
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head

    def print_list(self):
        cur = self.head

        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break

    def prepend(self, data):
        new_node = Node(data)
        cur = self.head
        new_node.next = self.head

        if self.head is None:
            new_node.next = new_node
        else:
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
        self.head = new_node
        
llist = CircularLinkedList()
llist.append(1)
llist.append(2)
llist.append(3)
llist.append(4)
llist.print_list()
llist.prepend(10)
llist.print_list()
# Out:
# 1
# 2
# 3
# 4
# 10
# 1
# 2
# 3
# 4

# %%
# Remove Node
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        if self.head is None:
            self.head = Node(data)
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head

    def print_list(self):
        cur = self.head

        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break

    def prepend(self, data):
        new_node = Node(data)
        cur = self.head
        new_node.next = self.head

        if self.head is None:
            new_node.next = new_node
        else:
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
        self.head = new_node

    def remove(self, key):
        if self.head:
            cur = self.head
            if self.head.data == key:
                while cur.next != self.head:
                    cur = cur.next
                if self.head == self.head.next:
                    self.head = None
                else:
                    cur.next = self.head.next
                    self.head = self.head.next
            else:
                prev = None
                while cur.next != self.head:
                    prev = cur
                    cur = cur.next
                    if cur.data == key:
                        prev.next = cur.next
                        cur = cur.next
                    
        
llist = CircularLinkedList()
llist.append(1)
llist.append(2)
llist.append(3)
llist.append(4)
llist.print_list()
print("remove 4")
llist.remove(4)
llist.print_list()
print("remove 1")
llist.remove(1)
llist.print_list()
print("remove 3")
llist.remove(3)
llist.print_list()
# Out:
# 1
# 2
# 3
# 4
# remove 4
# 1
# 2
# 3
# remove 1
# 2
# 3
# remove 3
# 2

# %%
# Split Linked List into Two Halves
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        if self.head is None:
            self.head = Node(data)
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head

    def print_list(self):
        cur = self.head

        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break

    def prepend(self, data):
        new_node = Node(data)
        cur = self.head
        new_node.next = self.head

        if self.head is None:
            new_node.next = new_node
        else:
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
        self.head = new_node

    def remove(self, key):
        if self.head:
            cur = self.head
            if self.head.data == key:
                while cur.next != self.head:
                    cur = cur.next
                if self.head == self.head.next:
                    self.head = None
                else:
                    cur.next = self.head.next
                    self.head = self.head.next
            else:
                prev = None
                while cur.next != self.head:
                    prev = cur
                    cur = cur.next
                    if cur.data == key:
                        prev.next = cur.next
                        cur = cur.next

    def __len__(self):
        cur = self.head
        count = 0
        while cur:
            cur = cur.next
            count += 1
            if cur == self.head:
                break
        return count

    def split_list(self):
        length = len(self)
        if length == 0:
            return None
        if size == 1:
            return self.head

        mid = length // 2
        cur = self.head
        prev = None
        count = 0
        while cur and count < mid:
            prev = cur
            cur = cur.next
            count += 1
        prev.next = self.head
        l = CircularLinkedList()
        while cur != self.head:
            l.append(cur.data)
            cur = cur.next
        self.print_list()
        print("\n")
        l.print_list()

        
llist = CircularLinkedList()
llist.append(1)
llist.append(2)
llist.append(3)
llist.append(4)
llist.split_list()
# print(llist.split_list())
# Out:
# 1
# 2
#
#
# 3
# 4

# %%
# Josephus Problem
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        if self.head is None:
            self.head = Node(data)
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head

    def print_list(self):
        cur = self.head

        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break

    def prepend(self, data):
        new_node = Node(data)
        cur = self.head
        new_node.next = self.head

        if self.head is None:
            new_node.next = new_node
        else:
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
        self.head = new_node

    def remove(self, key):
        if self.head:
            cur = self.head
            if self.head.data == key:
                while cur.next != self.head:
                    cur = cur.next
                if self.head == self.head.next:
                    self.head = None
                else:
                    cur.next = self.head.next
                    self.head = self.head.next
            else:
                prev = None
                while cur.next != self.head:
                    prev = cur
                    cur = cur.next
                    if cur.data == key:
                        prev.next = cur.next
                        cur = cur.next

    def remove_node(self, node):
        if self.head:
            cur = self.head
            if self.head == node:
                while cur.next != self.head:
                    cur = cur.next
                if self.head == self.head.next:
                    self.head = None
                else:
                    print("kill: {}".format(self.head.data))
                    cur.next = self.head.next
                    self.head = self.head.next
            else:
                prev = None
                while cur.next != self.head:
                    prev = cur
                    cur = cur.next
                    if cur == node:
                        print("kill: {}".format(cur.data))
                        prev.next = cur.next
                        cur = cur.next

    def __len__(self):
        cur = self.head
        count = 0
        while cur:
            cur = cur.next
            count += 1
            if cur == self.head:
                break
        return count

    def split_list(self):
        length = len(self)
        if length == 0:
            return None
        if length == 1:
            return self.head

        mid = length // 2
        cur = self.head
        prev = None
        count = 0
        while cur and count < mid:
            prev = cur
            cur = cur.next
            count += 1
        prev.next = self.head
        l = CircularLinkedList()
        while cur != self.head:
            l.append(cur.data)
            cur = cur.next
        self.print_list()
        print("\n")
        l.print_list()
    def josephus(self, step):
        cur = self.head
        while len(self) > 1:
            count = 1
            while count != step:
                cur = cur.next
                count += 1
            self.remove_node(cur)
            cur = cur.next

        
llist = CircularLinkedList()
llist.append(1)
llist.append(2)
llist.append(3)
llist.append(4)

llist.josephus(5)
llist.print_list()
# Out:
# kill: 1
# kill: 3
# kill: 4
# 2

# %%
# Is Ciruclar Linked List
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        if self.head is None:
            self.head = Node(data)
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head

    def print_list(self):
        cur = self.head

        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break

    def prepend(self, data):
        new_node = Node(data)
        cur = self.head
        new_node.next = self.head

        if self.head is None:
            new_node.next = new_node
        else:
            while cur.next != self.head:
                cur = cur.next
            cur.next = new_node
        self.head = new_node

    def remove(self, key):
        if self.head:
            cur = self.head
            if self.head.data == key:
                while cur.next != self.head:
                    cur = cur.next
                if self.head == self.head.next:
                    self.head = None
                else:
                    cur.next = self.head.next
                    self.head = self.head.next
            else:
                prev = None
                while cur.next != self.head:
                    prev = cur
                    cur = cur.next
                    if cur.data == key:
                        prev.next = cur.next
                        cur = cur.next

    def remove_node(self, node):
        if self.head:
            cur = self.head
            if self.head == node:
                while cur.next != self.head:
                    cur = cur.next
                if self.head == self.head.next:
                    self.head = None
                else:
                    print("kill: {}".format(self.head.data))
                    cur.next = self.head.next
                    self.head = self.head.next
            else:
                prev = None
                while cur.next != self.head:
                    prev = cur
                    cur = cur.next
                    if cur == node:
                        print("kill: {}".format(cur.data))
                        prev.next = cur.next
                        cur = cur.next

    def __len__(self):
        cur = self.head
        count = 0
        while cur:
            cur = cur.next
            count += 1
            if cur == self.head:
                break
        return count

    def split_list(self):
        length = len(self)
        if length == 0:
            return None
        if length == 1:
            return self.head

        mid = length // 2
        cur = self.head
        prev = None
        count = 0
        while cur and count < mid:
            prev = cur
            cur = cur.next
            count += 1
        prev.next = self.head
        l = CircularLinkedList()
        while cur != self.head:
            l.append(cur.data)
            cur = cur.next
        self.print_list()
        print("\n")
        l.print_list()
    def josephus(self, step):
        cur = self.head
        while len(self) > 1:
            count = 1
            while count != step:
                cur = cur.next
                count += 1
            self.remove_node(cur)
            cur = cur.next

    def is_circular_linked_list(self, input_list):
        cur = input_list.head
        while cur.next:
            cur = cur.next
            if cur == input_list.head:
                return True
        return False

        
clist = CircularLinkedList()
clist.append(1)
clist.append(2)
clist.append(3)
clist.append(4)

llist = LinkedList()
llist.append(1)
llist.append(2)
llist.append(3)
llist.append(4)
print(clist.is_circular_linked_list(clist))
print(clist.is_circular_linked_list(llist))
