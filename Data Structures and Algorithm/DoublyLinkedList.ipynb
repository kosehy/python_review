# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList():
    def __init__(self):
        self.head = None

    def append(self, data):
        if not self.head:
            self.head = Node(data)
            self.head.prev = None
        else:
            cur = self.head
            new_node = Node(data)
            while cur.next:
                cur = cur.next
            cur.next = new_node
            new_node.prev = cur
            new_node.next = None

    def print_list(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next

    def prepend(self, data):
        if self.head is None:
            new_node = data
            new_node.prev = None
            self.head = new_node
        else:
            new_node = Node(data)
            self.head.prev = new_node
            new_node.prev = None
            new_node.next = self.head
            self.head = new_node

        
d = DoublyLinkedList()
d.append(1)
d.append(2)
d.append(3)
d.append(4)
# d.print_list()
d.prepend(5)
d.print_list()
# Out:
# 5
# 1
# 2
# 3
# 4

# %%
# add node after & add node before
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList():
    def __init__(self):
        self.head = None

    def append(self, data):
        if not self.head:
            self.head = Node(data)
            self.head.prev = None
        else:
            cur = self.head
            new_node = Node(data)
            while cur.next:
                cur = cur.next
            cur.next = new_node
            new_node.prev = cur
            new_node.next = None

    def print_list(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next

    def prepend(self, data):
        if self.head is None:
            new_node = data
            new_node.prev = None
            self.head = new_node
        else:
            new_node = Node(data)
            self.head.prev = new_node
            new_node.prev = None
            new_node.next = self.head
            self.head = new_node

    def add_after_node(self, key, data):
        cur = self.head
        while cur:
            if cur.next is None and cur.data == key:
                self.append(data)
                return
            elif cur.data == key:
                new_node = Node(data)
                cur.next = new_node
                new_node.next = cur.next
                new_node.prev = cur
                cur.next.prev = new_node
                return
            cur = cur.next

    def add_before_node(self, key, data):
        cur = self.head
        while cur:
            if cur.prev is None and cur.data == key:
                self.prepend(data)
                return
            elif cur.data == key:
                new_node = Node(data)
                prev = cur.prev
                prev.next = new_node
                new_node.next = cur
                new_node.prev = prev
                cur.prev = new_node
                return
            cur = cur.next
        
d = DoublyLinkedList()
d.append(1)
d.append(2)
d.append(3)
d.append(4)
# d.print_list()
d.prepend(5)
d.add_after_node(4, 8)
d.add_before_node(5, 0)
d.print_list()
# Out:
# 0
# 5
# 1
# 2
# 3
# 4
# 8

# %%
# delete node
# case 1: delete only one node
# case 2: delete head node
# case 3: delete middle node
# case 4: delete tail node
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList():
    def __init__(self):
        self.head = None

    def append(self, data):
        if not self.head:
            self.head = Node(data)
            self.head.prev = None
        else:
            cur = self.head
            new_node = Node(data)
            while cur.next:
                cur = cur.next
            cur.next = new_node
            new_node.prev = cur
            new_node.next = None

    def print_list(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next

    def prepend(self, data):
        if self.head is None:
            new_node = data
            new_node.prev = None
            self.head = new_node
        else:
            new_node = Node(data)
            self.head.prev = new_node
            new_node.prev = None
            new_node.next = self.head
            self.head = new_node

    def add_after_node(self, key, data):
        cur = self.head
        while cur:
            if cur.next is None and cur.data == key:
                self.append(data)
                return
            elif cur.data == key:
                new_node = Node(data)
                cur.next = new_node
                new_node.next = cur.next
                new_node.prev = cur
                cur.next.prev = new_node
                return
            cur = cur.next

    def add_before_node(self, key, data):
        cur = self.head
        while cur:
            if cur.prev is None and cur.data == key:
                self.prepend(data)
                return
            elif cur.data == key:
                new_node = Node(data)
                prev = cur.prev
                prev.next = new_node
                new_node.next = cur
                new_node.prev = prev
                cur.prev = new_node
                return
            cur = cur.next

    def delete(self, key):
        cur = self.head
        while cur:
            # case 1: if list has only one node we want to delte
            if cur.data == key and cur == self.head
                if not cur.next:
                    cur = None
                    self.head = None
                    return
                else:
                    nxt = cur.next
                    #cur.next = None
                    cur.next = None
                    cur = None
                    nxt.prev = None
                    self.head = nxt
                    return
            elif cur.data == key:
                if cur.next:
                    prev = cur.prev
                    nxt = cur.next
                    nxt.prev = prev
                    prev.next = nxt
                    #cur.next = None
                    #cur.prev = None
                    cur.next = None
                    cur.prev = None
                    cur = None
                    return
                else:
                    prev = cur.prev
                    prev.next = None
                    #cur.prev = None
                    cur.prev = None
                    cur = None
                    return
            cur = cur.next


d = DoublyLinkedList()
d.append(1)
d.append(2)
d.append(3)
d.append(4)
d.delete(0)
d.print_list()
# Out:
# 1
# 2
# 3
# 4

# %%
# remove duplicates
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList():
    def __init__(self):
        self.head = None

    def append(self, data):
        if not self.head:
            self.head = Node(data)
            self.head.prev = None
        else:
            cur = self.head
            new_node = Node(data)
            while cur.next:
                cur = cur.next
            cur.next = new_node
            new_node.prev = cur
            new_node.next = None

    def print_list(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next

    def prepend(self, data):
        if self.head is None:
            new_node = data
            new_node.prev = None
            self.head = new_node
        else:
            new_node = Node(data)
            self.head.prev = new_node
            new_node.prev = None
            new_node.next = self.head
            self.head = new_node

    def add_after_node(self, key, data):
        cur = self.head
        while cur:
            if cur.next is None and cur.data == key:
                self.append(data)
                return
            elif cur.data == key:
                new_node = Node(data)
                cur.next = new_node
                new_node.next = cur.next
                new_node.prev = cur
                cur.next.prev = new_node
                return
            cur = cur.next

    def add_before_node(self, key, data):
        cur = self.head
        while cur:
            if cur.prev is None and cur.data == key:
                self.prepend(data)
                return
            elif cur.data == key:
                new_node = Node(data)
                prev = cur.prev
                prev.next = new_node
                new_node.next = cur
                new_node.prev = prev
                cur.prev = new_node
                return
            cur = cur.next

    def rotate(self):
        tmp = None
        cur = self.head
        while cur:
            tmp = cur.prev
            cur.prev = cur.next
            cur.next = tmp
            cur = cur.prev
        if tmp:
            self.head = tmp.prev
            
    def remove_duplicates(self):
        cur = self.head
        seen = dict()
        while cur:
            if cur.data in seen:
                prev = cur.prev
                self.delete_node(cur)
                cur = prev.next
            else:
                seen[cur.data] = 1
                cur = cur.next

    def delete_node(self, node):
        cur = self.head
        while cur:
            if cur == node and cur == self.head:
                if cur.next is None:
                    cur = None
                    self.head = None
                    return
                else:
                    nxt = cur.next
                    cur.next = None
                    nxt.prev = None
                    cur = None
                    self.head = nxt
                    return
            elif cur == node:
                if cur.next:
                    nxt = cur.next
                    prev = cur.prev
                    prev.next = nxt
                    nxt.prev = prev
                    cur.prev = None
                    cur.next = None
                    cur = None
                    return
                else:
                    prev = cur.prev
                    prev.next = None
                    cur.prev = None
                    cur = None
                    return
            cur = cur.next            

d = DoublyLinkedList()
d.append(1)
d.append(2)
d.append(3)
d.append(2)
d.append(3)
d.remove_duplicates()
d.print_list()
# Out:
# 1
# 2
# 3

# %%
# pairs with sums
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList():
    def __init__(self):
        self.head = None

    def append(self, data):
        if not self.head:
            self.head = Node(data)
            self.head.prev = None
        else:
            cur = self.head
            new_node = Node(data)
            while cur.next:
                cur = cur.next
            cur.next = new_node
            new_node.prev = cur
            new_node.next = None

    def print_list(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next

    def prepend(self, data):
        if self.head is None:
            new_node = data
            new_node.prev = None
            self.head = new_node
        else:
            new_node = Node(data)
            self.head.prev = new_node
            new_node.prev = None
            new_node.next = self.head
            self.head = new_node

    def add_after_node(self, key, data):
        cur = self.head
        while cur:
            if cur.next is None and cur.data == key:
                self.append(data)
                return
            elif cur.data == key:
                new_node = Node(data)
                cur.next = new_node
                new_node.next = cur.next
                new_node.prev = cur
                cur.next.prev = new_node
                return
            cur = cur.next

    def add_before_node(self, key, data):
        cur = self.head
        while cur:
            if cur.prev is None and cur.data == key:
                self.prepend(data)
                return
            elif cur.data == key:
                new_node = Node(data)
                prev = cur.prev
                prev.next = new_node
                new_node.next = cur
                new_node.prev = prev
                cur.prev = new_node
                return
            cur = cur.next

    def rotate(self):
        tmp = None
        cur = self.head
        while cur:
            tmp = cur.prev
            cur.prev = cur.next
            cur.next = tmp
            cur = cur.prev
        if tmp:
            self.head = tmp.prev
            
    def remove_duplicates(self):
        cur = self.head
        seen = dict()
        while cur:
            if cur.data in seen:
                prev = cur.prev
                self.delete_node(cur)
                cur = prev.next
            else:
                seen[cur.data] = 1
                cur = cur.next

    def delete_node(self, node):
        cur = self.head
        while cur:
            if cur == node and cur == self.head:
                if cur.next is None:
                    cur = None
                    self.head = None
                    return
                else:
                    nxt = cur.next
                    cur.next = None
                    nxt.prev = None
                    cur = None
                    self.head = nxt
                    return
            elif cur == node:
                if cur.next:
                    nxt = cur.next
                    prev = cur.prev
                    prev.next = nxt
                    nxt.prev = prev
                    cur.prev = None
                    cur.next = None
                    cur = None
                    return
                else:
                    prev = cur.prev
                    prev.next = None
                    cur.prev = None
                    cur = None
                    return
            cur = cur.next

    def pairs_with_sum1(self, sum_val):
        cur = self.head
        pair = []
        answer = []
        while cur:
            first = cur.data
            data = sum_val - first
            tmp = cur.next
            while tmp:
                if tmp.data == data:
                    pair.append(first)
                    pair.append(tmp.data)
                    answer.append(str(pair))
                    break
                tmp = tmp.next
            pair = []
            cur = cur.next
        return answer

    def pairs_with_sum(self, sum_val):
        p = self.head
        q = None
        pair = list()
        while p:
            q = p.next
            while q:
                if p.data + q.data == sum_val:
                    pair.append('(' + str(p.data) + ',' + str(q.data) + ')')
                q = q.next
            p = p.next
        return pair

d = DoublyLinkedList()
d.append(1)
d.append(2)
d.append(3)
d.append(4)
d.append(5)
d.append(6)
d.append(7)
print(d.pairs_with_sum(5))
# Out:
# ['(1,4)', '(2,3)']
